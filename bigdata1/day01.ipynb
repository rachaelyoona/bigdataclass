# %% [markdown]
# #1.오리엔테이션

# %% [markdown]
# ## 강사 소개
#
# 이름: 민지환
# 이메일: jhmin.megastudyitacademy@gmail.com
# 메일 보낼 시 유의사항:
#
# * 제목은 [bigdata_0930_이름] 질문 내용
# * 에러 문의 시 소스 코드, 에러 내용 반드시 첨부
# * 내가 시도한 내용을 첨부하는 것을 권장

# %% [markdown]
# # 2.환경설정

# %% [markdown]
# ## 2.1 python
#
# vscode: https://code.visualstudio.com/
# anaconda: https://www.anaconda.com/

# %% [markdown]
# ## 2.2 git
#
# git: https://git-scm.com/
# github: https://github.com/

# %% [markdown]
# ## 2.3 database
#
# docker: https://www.docker.com/
# dbeaver: https://dbeaver.io/download/

# %% [markdown]
# # 3.기본 파이썬 문법

# %% [markdown]
# ## 3.1 데이터 구조

# %% [markdown]
# ### 3.1.1 기본 자료형

# %% [markdown]
# #### 3.1.1.1 정수형
#
# int는 정수 자료형
# 기본적으로 원하는 값의 크기를 제한 없이 사용 가능

# %%
print(int(1.9))
print(int(True))
print(int(False))
print(int('100'))
# Out:
# 1
# 1
# 0
# 100

# %%
# 주의
print(int('100a'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [7], line 2
#       1 # 주의
# ----> 2 print(int('100a'))
#
# ValueError: invalid literal for int() with base 10: '100a'

# %% [markdown]
# #### 3.1.1.2 실수형
#
# float은 실수 자료형
# 기본적으로 소숫점이 있는 숫자를 실수(floating point number)라고 함
# 지수형식이나 복소수 형식으로 표현 가능
#
# |구분|특징|예시|의미|
# |----- |-----                         |-----      |-----|
# |실수  |소숫점이 있는 숫자            |3.14       |3.14
# |지수  |e를 포함하는 숫자             |1.5e2      |1.5*10^2|
# |복소수|실수와 허수(j)를 포함하는 숫자|1.5 + 2.54j|허수 i 대신 j나 J를 사용|

# %%
if 1.0 == 1:
    print(1)
else:
    print(0)
# Out:
# 1

# %%
print(float(1))
print(float(True))
print(float(False))
print(float('3.14'))
print(float('100'))
# Out:
# 1.0
# 1.0
# 0.0
# 3.14
# 100.0

# %%
print(int(3.14))
# Out:
# 3

# %% [markdown]
# #### 3.1.1.3 논리형
#
# bool은 논리 자료형.
# 참과 거짓을 의미하는 True와 False 값을 가질 수 있음.
#
# |구분|의미|예시|특징|
# |----- |-----|----- |-----|
# |True  |참   |True  |False 외 모든 값|
# |False |거짓 |False |0, '', [], {}, (), 등|
#
# >사용법
# * bool(0)
# * bool('')
# * bool([])

# %%
print(bool(0))
print(bool(''))  #string
print(bool([]))  #list
print(bool(()))  #set/dictionary
print(bool({}))  #tuple
# Out:
# False
# False
# False
# False
# False

# %%
print(bool(1))
print(bool(' '))
print(bool([1]))
print(bool((1,)))
print(bool({'a': 1}))
# Out:
# True
# True
# True
# True
# True

# %%
print(bool(1,)) #튜플 자료형 구분하기 위해 콤마를 찍어줘야함
# Out:
# True

# %% [markdown]
# #### 3.1.1.4 문자열
#
# str은 문자열 자료형
# 문자열은 기본적으로 따옴표로 묶어서 데이터 표현.
# '100'처럼 숫자로 구성되어 있어도 문자열.
# 문자열은 한 글자이거나 여러 글자여도 작은따옴표(')와 큰 따옴표(")를
# 모두 사용할 수 있으며, 각 따옴표를 3개씩 사용하는 삼중 따옴표(''' ''', """ """)도 사용 가능.
#
#
#
# |분류  |사용 기호|의미|예시|
# |----- |-----|----- |-----|
# |single line   |' '    |한 줄 문자열   |'python'|
# |              |" "    |               |"python"|
# |multiple line |''' '''|여러 줄 문자열 |''' python <br> is <br> interesting '''|
# |              |""" """|               |""" python <br> is <br> interesting """|

# %% [markdown]
# ##### 문자열 메서드

# %% [markdown]
# count()
# 문자열 내부에 포함된 특정 문자열의 개수를 반환하는 메소드
#
# 인덱스를 지정해 검색 범위를 지정할 수도 있음

# %%
print('apple watch is very expensive'.count('a'))
print('apple watch is very expensive'.count('apple'))
print('apple watch is very expensive'.count('samsung'))
# Out:
# 2
# 1
# 0

# %%
"apple's application is a very good app".count('app') #문자열 내에 단순히 매칭함
# Out:
# 3

# %% [markdown]
# find()
# 문자열 내부에 포함된 특정 문자열을 찾고자 할 때 사용
# 찾고자하는 문자열이 있으면 그 문자열이 처음으로 나온 위치(인덱스)를 반환
# 만일 찾고자 하는 문자열이 없는 경우 -1을 반환
#
# 인덱스를 이용해 검색 범위 지정 가능
# 지정하지 않으면 처음부터 찾고,
# 시작할 인덱스를 지정하는 경우에도 지정된 인덱스부터 찾음
#
# rfind()메소드를 통해 오른쪽에서부터 값을 탐색 가능

# %%
print('apple watch is very expensive'.find('a')) #있는지 없는지 확인 용도_위치 인덱스를 반환하고 종료함
print('apple watch is very expensive'.find('watch')) 
print('apple watch is very expensive'.find('samsung'))
# Out:
# 0
# 6
# -1

# %%
#안녕하세요 여러분 반갑습니다. 오늘은 파이썬 첫 수업 시간입니다. 
#"파이썬"이라는 단어가 문장에 존재하면, "존재", 없으면 "미존재"라고 출력하는 코드 작성 

# string = "안녕하세요 여러분 반갑습니다. 오늘은 파이썬 첫 수업 시간입니다.".find("파이썬")

# if string >= 0: 
#     print("존재")
# else:
#     print("미존재")

string = "안녕하세요 여러분 반갑습니다. 오늘은 파이썬 첫 수업 시간입니다."
if string.find("파이썬") == -1:
    print("미존재")
else:
    print("존재")
# Out:
# 존재

# %% [markdown]
# 대소문자 변환
#
# |메소드|의미|
# |------|----|
# |upper()|모두 대문자로 변환한 결과를 반환|
# |lower()|모두 소문자로 변환한 결과를 반환|
# |capitalize()|첫 글자는 대문자로 변환하고 나머지 문자는 소문자로 변환한 결과 반환|

# %%
print('apple'.upper())
print('apPle'.upper())
print('apPle'.lower())
print('APPLE'.lower())
print('apple is good'.capitalize())
# Out:
# APPLE
# APPLE
# apple
# apple
# Apple is good

# %% [markdown]
# join()
# 인수로 전달한 반복가능객체(문자열, 리스트 등)의 각 요소 사이에
# 문자열을 포함시켜 새로운 문자열을 만들고 그 결과를 반환

# %%
#권장 방식 
texts = ['apple', 'is', 'very', 'expensive']
' '.join(texts).capitalize()
# Out:
# 'Apple is very expensive'

# %% [markdown]
# split()
#
# 하나의 문자열을 여러 개의 문자열로 분리 후 리스트로 반환하는 메소드
# 기본적으로는 공백문자로 분리하지만 특정 문자열을 기준으로 분리 가능

# %%
'apple is very expensive'.split()
'apple_is_very_expensive'.split('_')
# Out:
# ['apple', 'is', 'very', 'expensive']

# %% [markdown]
# 불필요한 문자열 제거 메소드
#
# |메소드|의미|
# |--------|--------|
# |lstrip  |왼쪽 끝에 있는 공백을 제거 후 반환|
# |rstrip  |오른쪽 끝에 있는 공백을 제거 후 반환|
# |strip   |양쪽 끝에 있는 공백을 제거 후 반환|

# %%
print('                apple is very expensive               ')
print('                apple is very expensive               '.lstrip())
print('                apple is very expensive               '.rstrip())
print('                apple is very expensive               '.strip())
# Out:
#                 apple is very expensive
# apple is very expensive
#                 apple is very expensive
# apple is very expensive

# %% [markdown]
# ### 3.2.1 컬렉션

# %% [markdown]
# ##### 3.2.1.1 리스트
#
# 리스트는 여러 값을 저장할 때 가장 많이 사용하는 자료형.
# 저장하고자 하는 값의 자료형이 서로 다르더라도 하나의 리스트에 저장 가능.
#
# > 사용법
# - [값1, 값2]
# - list(반복가능객체)
# <br>
#
# 하나의 배열에 하나의 자료형만 저장할 수 있는 C나 자바에 비하면 매우 큰 장점.
# <br>
# <br>
# 리스트는 문자열과 동일한 방식의 인덱싱 지원.
#
# li = [100, 3.14, 'hello']
#
# |li|100|3.14|'hello'|
# |-|-|-|-|
# |index|0|1|2|
# <br>
#
# |100|3.14|'hello'|
# |-|-|-|
# |li[0]|li[1]|li[2]|
# <br>
#
# 슬라이싱
#
# li = [10, 20, 30, 40, 50]
# li[0:3]

# %% [markdown]
# ###### 리스트 메서드

# %% [markdown]
# append()
#
# 리스트 끝에 인수로 전달된 데이터를 추가

# %%
#string = hello
#i)   o    출력
#ii)  hel  출력
#iii) hlo  출력
#iv) olleh 출력

string = "hello" 
print(string[-1]) #-1은 항상 문자의 마지막을 불러옴 
print(string[:3]) #포함
print(string[2:]) #미포함
print(string[::2]) 
print(string[::-1])
# Out:
# o
# hel
# llo
# hlo
# olleh

# %% [markdown]
# insert()
#
# 리스트의 특정 인덱스에 데이터를 추가하는 메소드

# %%
a = []
a.append(1)
a.append(2)
a.append([2])
a.append((2,3))
print(a)

print(a[2])
print(a[3])
print(a[-1][0])
print(a[-1][1])
# Out:
# [1, 2, [2], (2, 3)]
# [2]
# (2, 3)
# 2
# 3

# %%
#[1, 2, [2], (2, 3)]
a.insert(1, [3, 4, 5])
print(a)
# Out:
# [1, [3, 4, 5], 2, [2], (2, 3)]

# %% [markdown]
# count()
#
# 리스트 내에 매칭되는 원소의 개수를 반환

# %%
a = [1, 1.0, 1, 2, 3, 'apple', 'APPLE']
print(a.count(2))
print(a.count(1))
print(a.count('apple'))    #소문자 대문자 다르게 인식함 
print(a.count('APPLE'))
# Out:
# 1
# 3
# 1
# 1

# %% [markdown]
# sort()
#
# 주어진 리스트를 정렬

# %%
a = [1, 5, 3, 4, 6, 2]
a.sort()
print(a)
# a.reverse()
# print(a)
a.sort(reverse=True)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]
# [6, 5, 4, 3, 2, 1]

# %%
a = ['banana', 'apple', "kiwi"]
a.sort()
print(a)

a.sort(reverse=True)
print(a)

a.sort(key=len)
print(a)

a.sort(key=len, reverse=True)
print(a)
# Out:
# ['apple', 'banana', 'kiwi']
# ['kiwi', 'banana', 'apple']
# ['kiwi', 'apple', 'banana']
# ['banana', 'apple', 'kiwi']

# %% [markdown]
# #### 3.2.1.2 튜플
#
# 튜플은 저장된 값을 변경할 수 없는 리스트.
# 리스트와 마찬가지로 튜플도 각 요소를 구분하기 위한
# 인덱스가 부여되고 슬라이싱도 지원.
# 다만 이미 저장된 값 이외에는 추가, 수정 삭제 불가능.
# <br>
#
# >사용법
# * (값1, 값2, ...)
# * tuple(반복가능객체)
# <br>
#
# 또한, 소괄호나 tuple 함수를 사용하지 않고 ,로 분리하여 전달하면 자동으로 튜플 생성.
# * 값1, 값2
# <br>
#
# 다만 주의점은 값을 1개만 보관하는 튜플을 생성할 경우 다음과 같이 ,를 반드시 함께 작성
# * (값, )

# %% [markdown]
# #### 3.2.1.3 세트 *중복값 제거용도
#
# 세트는 수학의 집합을 구현한 자료형.
# 세트에 저장된 값들은 순서가 없기 때문에 인덱싱과 슬라이싱 불가.
# 대신 중복 값 저장이 불가능하다는 특징을 활용해 중복 제거용으로 사용하거나
# 교집합, 합집합, 차집합과 같은 집합 개념이 필요한 경우 사용
#
# >사용법
# * {값1, 값2}
# * set(반복가능객체)
# <br>
#
# 다만 빈 세트 사용 시에는 중괄호를 사용할 수 없음. (이는 딕셔너리)
# 빈 세트 생성 시 set 함수 이용

# %%
#using intersections & unions to create a numerical difference value between two sentences
#jaccard similarity

'''
The Jaccard similarity index measures the similarity between two sets of data. 
It can range from 0 to 1. The higher the number, the more similar the two sets of data.

The Jaccard similarity index is calculated as:

Jaccard Similarity = (number of observations in both sets) / (number in either set)

Or, written in notation form:

J(A, B) = |A∩B| / |A∪B|
'''


a = [0, 1, 2, 5, 6, 8, 9]
b = [0, 2, 3, 4, 5, 7, 9]

#define Jaccard Similarity function
def jaccard(list1, list2):
    intersection = len(list(set(list1).intersection(list2)))
    union = (len(list1) + len(list2)) - intersection
    return float(intersection) / union

#find Jaccard Similarity between the two sets 
jaccard(a, b)
# Out:
# 0.4

# %% [markdown]
# #### 3.2.1.4 딕셔너리
#
# 딕셔너리는 말 그대로 사전을 의미.
# 파이썬에서는 '키'와 '값'을 '단어'와 '단어의 의미'처럼 사용.
#
#
#
# > 사용법
# 1. dict = {키1: 값1, 키2: 값2, ...}
# -> 가장 많이 사용하는방법
#
#
# 2. dict = dict(키1=값1, 키2=값2)
# 3. dict = dict([(키1, 값1), (키2, 값2)])
#
#
# 4. dict = dict({키1: 값1, 키2: 값2})
#
#
# 5. dict = dict(zip([키1, 키2], [값1, 값2]))

# %%
print({'이름': "홍길동", '나이' : 16, '직업': '학생' })
print(dict(이름="홍길동", 나이=16, 직업='학생'))
print(dict([("이름", "홍길동"), ("나이", 16), ("직업",'학생')]))
print(dict({'이름': '홍길동', '나이': 16, '직업': '학생'}))
print(dict(zip(['이름', '나이', "직업"], ['홍길동', 16, '학생'])))
# Out:
# {'이름': '홍길동', '나이': 16, '직업': '학생'}
# {'이름': '홍길동', '나이': 16, '직업': '학생'}
# {'이름': '홍길동', '나이': 16, '직업': '학생'}
# {'이름': '홍길동', '나이': 16, '직업': '학생'}
# {'이름': '홍길동', '나이': 16, '직업': '학생'}

# %% [markdown]
# ##### 딕셔너리 메서드

# %% [markdown]
# keys()
# *중복 불가능

# %%
a = {'이름': "홍길동", '나이' : 16, '직업': '학생' }
print(a.keys())
# Out:
# dict_keys(['이름', '나이', '직업'])

# %%
print('이름' in a.keys())
print('주소' in a.keys())
print('이름' in a)           #권장방식 - 어차피 키로 비교하기에, 불필요한 요소를 제거하는 것 
print('주소' in a)
# Out:
# True
# False
# True
# False

# %% [markdown]
# values()

# %%
a = {'이름': "홍길동", '나이' : 16, '직업': '학생' }
a.values()
# Out:
# dict_values(['홍길동', 16, '학생'])

# %%
print('홍길동' in a.values())
print('임꺽정' in a.values())
print(20 in a.values())
# Out:
# True
# False
# False

# %% [markdown]
# items()

# %%
a = {'이름': "홍길동", '나이' : 16, '직업': '학생' }
a.items()
# Out:
# dict_items([('이름', '홍길동'), ('나이', 16), ('직업', '학생')])

# %% [markdown]
# get()

# %%
a = {'이름': "홍길동", '나이' : 16, '직업': '학생' }
# a['주소']
a.get('조소')

# %% [markdown]
# update()

# %%
a = {'이름': "홍길동", '나이' : 16, '직업': '학생' }
# a['주소'] = '서울'
a.update({'주소': '서울'})
a.update({'이름': '임꺽정'}) #키가 중복되면 나중 값으로 업데이트됨
a
# Out:
# {'이름': '임꺽정', '나이': 16, '직업': '학생', '주소': '서울'}

# %% [markdown]
# ## 3.2 조건문

# %% [markdown]
# ### 3.2.1 if

# %% [markdown]
# 파이썬은 이와 같은 상황에서 사용할 수 있는 if문 제공
#
# 사용법
# * if 조건식:
# <br>&nbsp;&nbsp;&nbsp;&nbsp;조건식의 결과가 True일 때 실행문
#
# <br>
# 조건식의 결과가 True 이면 실행문이 동작하고,
# 조건식의 결과가 False면 실행문이 동작하지 않음.
# <br>
#
# **※주의**
# 파이썬은 타 언어와 다르게 코드 블록을 나타내는
# 중괄호({})가 없는 대신 들여쓰기로 구분.
# 따라서 다음과 같이 쓸 경우 오류 발생.
#
# * if 조건식:
# <br>조건식의 결과가 True일 때 실행문
#
#
# 들여쓰기 규칙은 다음과 같음
# 1. 공백이나 탭을 이용하여 들여쓰기 수행
# 2. 공백의 개수는 상관 없음
# 그러나 파이썬 스타일 가이드(PEP 8)에 따르면 공백의 개수는 4개 사용.
# 3. 탭은 1개만 사용
# 4. 동일 구역에서 들여쓰기는 통일
# (탭과 공백을 혼용하여 사용할 수 없고, 들여쓰기 수준도 동일)

# %%
x = int(input('시험 점수를 입력해주세요: '))

if x >= 90 : 
    print('최종성적은 A입니다.')
elif x >= 80 :
    print('최종성적은 B입니다.')
elif x >= 70: 
    print('최종성적은 C입니다.')
elif x >= 60:
    print('최종성적은 D입니다.')
else:
    print('최종성적은 F입니다.')
# Out:
# 최종성적은 F입니다.

# %% [markdown]
# if-else
#
# if-else문은 조건식을 만족하는 경우와 만족하지 않는 경우를
# 구분할 필요가 있을 시 사용.
#
# 사용법
# * if 조건식:
# <br>&nbsp;&nbsp;&nbsp;&nbsp;조건식의 결과가 True일 때 실행문
#   else:
# <br>&nbsp;&nbsp;&nbsp;&nbsp;조건식의 결과가 False일 때 실행문
#
# 조건식의 결과가 True인 경우와 False인 경우로 구분하여 코드 작성 가능.

# %% [markdown]
# if-elif
#
# if-elif문은 특정 조건에 따라 3가지 이상으로 구분해야 할 때 사용.
# 여기서 elif는 else if
#
# 사용법
# * if 조건식1:
# <br>&nbsp;&nbsp;&nbsp;&nbsp;조건식1의 결과가 True일 때 실행문
#   elif 조건식2:
# <br>&nbsp;&nbsp;&nbsp;&nbsp;조건식1의 결과가 False이고 조건식2의 결과가 True일 때 실행문.
#   elif 조건식3:
# <br>&nbsp;&nbsp;&nbsp;&nbsp;조건식1, 2의 결과가 False이고 조건식 3의 결과가 True일 때 실행문

# %% [markdown]
# if-elif-else
#
# if-elif문은 특정 조건에 따라 구분 후 위의 조건을 만족하는 않는
# 모든 경우에 대해 실행을 할 때 사용.
#
# 사용법
# * if 조건식1:
# <br>&nbsp;&nbsp;&nbsp;&nbsp;조건식1의 결과가 True일 때 실행문
#   elif 조건식2:
# <br>&nbsp;&nbsp;&nbsp;&nbsp;조건식1의 결과가 False이고 조건식2의 결과가 True일 때 실행문.
#   elif 조건식3:
# <br>&nbsp;&nbsp;&nbsp;&nbsp;조건식1, 2의 결과가 False이고 조건식 3의 결과가 True일 때 실행문
#   else:
# <br>&nbsp;&nbsp;&nbsp;&nbsp;조건식1, 2, 3이 모두 False일 때 실행될 문장.
